# %% [markdown]
# # DataScienceEcosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# **Objectives of the notebook**
# -List popular languages in datascience
# -List popular librairies in datascience
# -List popular data science tools
# -Evaluate arithmetic expression in notebook
# -Share a notebook on github

# %% [markdown]
# *Some of the _popular language_ __Data Science__ uses are :*
# - Python
# - R
# - Julia

# %% [markdown]
# *Some of the commonly used librairy used by data scientist are :*
# ** In python**
# - Matplotlib for visualisation
# - Numpy to work with matrix
# - Pandas built on top of matplotlib
# - scilkit learn librairi for machine learning
# **In Apache**
# -Apache spark
# -Vegas
# **In R**
# - ggplot2 for visualisation

# %% [markdown]
# |Data Science Tool|
# |:------|
# |Jupyter|
# |Anaconda|
# |Gitlab|

# %% [markdown]
# ### Below are few example of evaluating arithmetic expression with python

# %%
# exemple d'addition et multiplication d'integer
(3*4)+5
# Out:
# 17

# %%
# Conversion de 200 minutes en heures
min = 200
heure = 200/60
heure
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author : Laurent Dalzon
